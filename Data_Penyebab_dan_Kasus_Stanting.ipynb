# %% [markdown]
# <a href="https://colab.research.google.com/github/putrilestari434/KecerdasanBuatan/blob/main/Data_Penyebab_dan_Kasus_Stanting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-67de84b8-9519-4759-8f80-a83b41b516c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67de84b8-9519-4759-8f80-a83b41b516c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_penerima = pd.read_csv('Data Penyebab Stanting.csv')
df_penerima.head(10)
# Out:
#           Penyebab Stanting;Jumlah
# 0         Makanan tak bergizi;32.4
# 1  Kurang Gizi pada Ibu Hamil;28.2
# 2                     Genetik;16.2
# 3       Kebersihan tak terjaga;4.8
# 4        inveksi virus/bakteri;4.1
# 5       Tingkat ekonomi Rendah;2.8
# 6                 Lain - Lainnya;3
# 7                   Tidak tahu;8.5

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_0.groupby('Penyebab Stanting;Jumlah').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_penerima = pd.read_csv('Stunting Kelurahan Semarang.csv')
df_penerima.head(60)
# Out:
#    Kelurahan;Jumlah Stunting
# 0             Lamper Kidul;4
# 1                 Pleburan;5
# 2                Mugassari;6
# 3                 Barusari;7
# 4               Lamper Lor;7
# 5               Bulustalan;8
# 6                 Wonodri;11
# 7              Peterongan;11
# 8               Randusari;12
# 9           Lamper Tengah;22
# 10            Karangtempel;1
# 11              Karangturi;2
# 12                Bugangan;2
# 13              Kebonagung;3
# 14                Rejosari;7
# 15               Rejomulyo;9
# 16             Mlatiharjo;10
# 17               Sarirejo;13
# 18              Mlatibaru;22
# 19                Kemijen;49
# 20                 Krapyak;0
# 21            Salamanmloyo;1
# 22             Tawang Sari;1
# 23                  Cabean;2
# 24       Kalibanteng Kidul;2
# 25             Tambakharjo;3
# 26               Karangayu;7
# 27          Bojong Salaman;7
# 28       Kalibanteng Kulon;7
# 29             Tawang Mas;12
# 30      Ngemplak Simongan;12
# ...
